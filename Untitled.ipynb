# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
data = pd.read_csv('Laptop_price.csv')
data
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 0      Asus         3.830296        16               512    11.185147
# 1      Acer         2.912833         4              1000    11.311372
# 2    Lenovo         3.241627         4               256    11.853023
# 3      Acer         3.806248        16               512    12.280360
# 4      Acer         3.268097        32              1000    14.990877
# ..      ...              ...       ...               ...          ...
# 995      HP         3.343584         4              1000    12.587095
# 996    Dell         2.780555         8               256    12.679356
# 997    Dell         3.200569         4               512    12.666315
# 998    Asus         1.604182         8               256    11.215581
# 999  Lenovo         1.711980         4               256    16.561498
#
#        Weight         Price
# 0    2.641094  17395.093065
# 1    3.260012  31607.605919
# 2    2.029061   9291.023542
# ...

# %%
data.isnull().sum()
# Out:
# Brand               0
# Processor_Speed     0
# RAM_Size            0
# Storage_Capacity    0
# Screen_Size         0
# Weight              0
# Price               0
# dtype: int64

# %%
data['Brand'] = data['Brand'].astype('category').cat.codes
data
# Out:
#      Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 0        1         3.830296        16               512    11.185147
# 1        0         2.912833         4              1000    11.311372
# 2        4         3.241627         4               256    11.853023
# 3        0         3.806248        16               512    12.280360
# 4        0         3.268097        32              1000    14.990877
# ..     ...              ...       ...               ...          ...
# 995      3         3.343584         4              1000    12.587095
# 996      2         2.780555         8               256    12.679356
# 997      2         3.200569         4               512    12.666315
# 998      1         1.604182         8               256    11.215581
# 999      4         1.711980         4               256    16.561498
#
#        Weight         Price
# 0    2.641094  17395.093065
# 1    3.260012  31607.605919
# 2    2.029061   9291.023542
# ...

# %%
x = data.drop(["Price"], axis=1)
y = data.Price

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
data.corr()
# Out:
#                      Brand  Processor_Speed  RAM_Size  Storage_Capacity  \
# Brand             1.000000        -0.006958  0.013622         -0.008166
# Processor_Speed  -0.006958         1.000000  0.021391         -0.067576
# RAM_Size          0.013622         0.021391  1.000000          0.002111
# Storage_Capacity -0.008166        -0.067576  0.002111          1.000000
# Screen_Size      -0.031384        -0.013425 -0.036002         -0.027560
# Weight           -0.022911        -0.054603 -0.025382          0.041335
# Price            -0.008365        -0.050737  0.061237          0.997908
#
#                   Screen_Size    Weight     Price
# Brand               -0.031384 -0.022911 -0.008365
# Processor_Speed     -0.013425 -0.054603 -0.050737
# RAM_Size            -0.036002 -0.025382  0.061237
# Storage_Capacity    -0.027560  0.041335  0.997908
# Screen_Size          1.000000  0.021995 -0.026740
# Weight               0.021995  1.000000  0.038417
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2, random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()

model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
pred = model.predict(x_test)

# %%
error_score = metrics.r2_score(y_test, pred)


print(model.score(x_train, y_train))
print(model.score(x_test, y_test))
print(error_score)
print(mean_squared_error(y_test, pred))
# Out:
# 0.9999221422549768
# 0.9994788223519526
# 0.9994788223519526
# 45584.639429188996

# %%
data.tail()
# Out:
#      Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 995      3         3.343584         4              1000    12.587095
# 996      2         2.780555         8               256    12.679356
# 997      2         3.200569         4               512    12.666315
# 998      1         1.604182         8               256    11.215581
# 999      4         1.711980         4               256    16.561498
#
#        Weight         Price
# 995  3.162399  31593.668017
# 996  3.750265   9149.521832
# 997  3.392612  16552.404779
# 998  3.857613   9407.473459
# 999  3.440883   8807.696702

# %%
import pandas as pd

input_data = pd.DataFrame({
    'Brand': [0],
    'Processor_Speed': [3.806248],  #'Processor_Speed'
    'RAM_Size': [16],         #'RAM_Size'
    'Storage_Capacity': [512], #'Storage_Capacity'
    'Operating System': [1],  # If this was in training data, keep it
    'Screen_Size': [12.280360],     #'Screen_Size'
    'Weight': [4.573865],            # If this was in training data, keep it
})

training_columns = x_train.columns
input_data = input_data.reindex(columns=training_columns, fill_value=0)

# Price in Dataset 17436.728334
prediction = model.predict(input_data)
print("prediction1", prediction)



# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # #

input_data = pd.DataFrame({
    'Brand': [2],
    'Processor_Speed': [2.780555],  #'Processor_Speed'
    'RAM_Size': [8],         #'RAM_Size'
    'Storage_Capacity': [256], #'Storage_Capacity'
    'Operating System': [1],  # If this was in training data, keep it
    'Screen_Size': [12.679356],     #'Screen_Size'
    'Weight': [3.750265],            # If this was in training data, keep it
})

training_columns = x_train.columns
input_data = input_data.reindex(columns=training_columns, fill_value=0)


# Price in Dataset 9149.521832
prediction2 = model.predict(input_data)
print("prediction2", prediction2)
# Out:
# prediction1 [17655.21934085]
# prediction2 [9203.86584688]
